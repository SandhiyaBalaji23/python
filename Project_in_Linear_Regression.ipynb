# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Training_Data_set.csv")

# %%
df.head()
# Out:
#       Id   Maker    model   Location  Distance       Owner Type  \
# 0  25001   skoda  octavia  Ahmedabad        NaN          Second
# 1  25002    fiat    panda  Ahmedabad    27750.0           Third
# 2  25003     bmw       x1  Hyderabad    46000.0           Third
# 3  25004  nissan     juke     Mumbai    43949.0           Third
# 4  25005     bmw       x5     Jaipur    59524.0  Fourth & Above
#
#    manufacture_year  Age of car  engine_displacement  engine_power body_type  \
# 0              1964          55                 1964         147.0   compact
# 1              2012           7                 1242          51.0       NaN
# 2              2014           5                 1995         105.0       NaN
# 3              2011           8                 1618         140.0       NaN
# 4              2012           7                 2993         180.0       NaN
#
#    Vroom Audit Rating transmission  door_count  seat_count fuel_type  \
# ...

# %%
df.shape
# Out:
# (53515, 17)

# %%
df.isnull().sum()
# Out:
# Id                         0
# Maker                      0
# model                      0
# Location                   0
# Distance                1211
# Owner Type                 0
# manufacture_year           0
# Age of car                 0
# engine_displacement        0
# engine_power            1439
# body_type              49379
# Vroom Audit Rating         0
# transmission               0
# door_count              7534
# seat_count              8511
# fuel_type                  0
# Price                      0
# dtype: int64

# %%
df.drop(columns="body_type",inplace=True)

# %%
df.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'Vroom Audit Rating', 'transmission', 'door_count', 'seat_count',
#        'fuel_type', 'Price'],
#       dtype='object')

# %%
(df['Distance '].isnull().sum()/len(df))*100
# Out:
# np.float64(2.262916939175932)

# %%
df["Distance "].fillna(df["Distance "].median(),inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_30616\2368577982.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Distance "].fillna(df["Distance "].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance                  0
# Owner Type                0
# manufacture_year          0
# Age of car                0
# engine_displacement       0
# engine_power           1439
# Vroom Audit Rating        0
# transmission              0
# door_count             7534
# seat_count             8511
# fuel_type                 0
# Price                     0
# dtype: int64

# %%
df["engine_power"].fillna(df["engine_power"].mean(),inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_30616\3545825698.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["engine_power"].fillna(df["engine_power"].mean(),inplace=True)

# %%
df["door_count"].fillna(df["door_count"].mean(),inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_30616\1916838230.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["door_count"].fillna(df["door_count"].mean(),inplace=True)

# %%
df["seat_count"].fillna(df["seat_count"].mean(),inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_30616\1757965507.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["seat_count"].fillna(df["seat_count"].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# Price                  0
# dtype: int64

# %%
pd.get_dummies(data=df,columns=['model'],prefix='model') #onehot encoding
# Out:
#           Id   Maker   Location  Distance       Owner Type  manufacture_year  \
# 0      25001   skoda  Ahmedabad    65520.0          Second              1964
# 1      25002    fiat  Ahmedabad    27750.0           Third              2012
# 2      25003     bmw  Hyderabad    46000.0           Third              2014
# 3      25004  nissan     Mumbai    43949.0           Third              2011
# 4      25005     bmw     Jaipur    59524.0  Fourth & Above              2012
# ...      ...     ...        ...        ...             ...               ...
# 53510  78511   skoda      Delhi    29334.0  Fourth & Above              2014
# 53511  78512   skoda  Bangalore   223631.0  Fourth & Above              2009
# 53512  78513     bmw       Pune    25500.0           Third              2015
# 53513  78514  toyota     Jaipur  1195500.0           Third              2011
# 53514  78515     bmw      Kochi   142000.0           First              2008
#
# ...

# %%
df.replace({'Truue':1,'False':0})
# Out:
#           Id   Maker    model   Location  Distance       Owner Type  \
# 0      25001   skoda  octavia  Ahmedabad    65520.0          Second
# 1      25002    fiat    panda  Ahmedabad    27750.0           Third
# 2      25003     bmw       x1  Hyderabad    46000.0           Third
# 3      25004  nissan     juke     Mumbai    43949.0           Third
# 4      25005     bmw       x5     Jaipur    59524.0  Fourth & Above
# ...      ...     ...      ...        ...        ...             ...
# 53510  78511   skoda  octavia      Delhi    29334.0  Fourth & Above
# 53511  78512   skoda  octavia  Bangalore   223631.0  Fourth & Above
# 53512  78513     bmw       x1       Pune    25500.0           Third
# 53513  78514  toyota  avensis     Jaipur  1195500.0           Third
# 53514  78515     bmw       x5      Kochi   142000.0           First
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# 0                  1964          55                 1964         147.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                   object
# model                   object
# Location                object
# Distance               float64
# Owner Type              object
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission            object
# door_count             float64
# seat_count             float64
# fuel_type               object
# Price                  float64
# dtype: object

# %%
df.select_dtypes(include=object)
# Out:
#         Maker    model   Location      Owner Type transmission fuel_type
# 0       skoda  octavia  Ahmedabad          Second          man    petrol
# 1        fiat    panda  Ahmedabad           Third          man    petrol
# 2         bmw       x1  Hyderabad           Third         auto    diesel
# 3      nissan     juke     Mumbai           Third          man    petrol
# 4         bmw       x5     Jaipur  Fourth & Above         auto    diesel
# ...       ...      ...        ...             ...          ...       ...
# 53510   skoda  octavia      Delhi  Fourth & Above          man    diesel
# 53511   skoda  octavia  Bangalore  Fourth & Above          man    diesel
# 53512     bmw       x1       Pune           Third         auto    diesel
# 53513  toyota  avensis     Jaipur           Third          man    diesel
# 53514     bmw       x5      Kochi           First         auto    diesel
#
# [53515 rows x 6 columns]

# %%
df["model"].value_counts()
# Out:
# model
# octavia     12619
# superb       3195
# yaris        3176
# qashqai      2854
# x3           2779
# x1           2420
# i30          2047
# q5           2039
# x5           1979
# yeti         1898
# panda        1769
# q3           1736
# coupe        1710
# micra        1676
# auris        1666
# avensis      1512
# aygo         1486
# rapid        1409
# roomster     1322
# q7           1245
# citigo       1120
# juke          955
# tt            903
# Name: count, dtype: int64

# %%
df["Maker"].unique()
# Out:
# array(['skoda', 'fiat', 'bmw', 'nissan', 'audi', 'toyota', 'hyundai',
#        'maserati'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df["Maker"]=le.fit_transform(df["Maker"])

# %%
df["Location"]=le.fit_transform(df["Location"])

# %%
df["model"]=le.fit_transform(df["model"])

# %%
df["Owner Type"]=le.fit_transform(df["Owner Type"])

# %%
df["transmission"]=le.fit_transform(df["transmission"])

# %%
df["fuel_type"]=le.fit_transform(df["fuel_type"])

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                    int64
# model                    int64
# Location                 int64
# Distance               float64
# Owner Type               int64
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission             int64
# door_count             float64
# seat_count             float64
# fuel_type                int64
# Price                  float64
# dtype: object

# %%
df.boxplot()
plt.show()

# %%
q1=df.quantile(0.25)

# %%
q3=df.quantile(0.75)

# %%
iqr=q3-q1

# %%
l1=q1-(1.5*iqr)

# %%
u1=q3+(1.5*iqr)

# %%
df_outliers_removed=df[(df>l1)&(df<u1)]

# %%
df_outliers_removed.boxplot()
plt.show()

# %%
df_outliers_removed.isnull().sum()
# Out:
# Id                         0
# Maker                      0
# model                      0
# Location                   0
# Distance                 595
# Owner Type                 0
# manufacture_year        1325
# Age of car              1325
# engine_displacement     5651
# engine_power            1407
# Vroom Audit Rating         0
# transmission               0
# door_count             53515
# seat_count              6180
# fuel_type                  0
# Price                   1948
# dtype: int64

# %%
df_outliers_removed['Distance '].median()
# Out:
# np.float64(65520.0)

# %%
df_outliers_removed['Distance '].fillna(df_outliers_removed['Distance '].median(),inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_30616\1934537390.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_outliers_removed['Distance '].fillna(df_outliers_removed['Distance '].median(),inplace=True)

# %%
df_outliers_removed['Distance '].isnull().sum()
# Out:
# np.int64(0)

# %%
q1=df_outliers_removed['Distance '].quantile(0.25)
q1
# Out:
# np.float64(16507.0)

# %%
q3=df_outliers_removed['Distance '].quantile(0.75)
q3
# Out:
# np.float64(129000.0)

# %%
iqr=q3-q1
iqr
# Out:
# np.float64(112493.0)

# %%
LL=q1-(1.5*iqr)
LL
# Out:
# np.float64(-152232.5)

# %%
UL=q3+(1.5*iqr)
UL
# Out:
# np.float64(297739.5)

# %%
df_outliers_removed['Distance']=df_outliers_removed['Distance '][(df_outliers_removed['Distance ']>LL)& (df_outliers_removed['Distance ']<UL)]

# %%
df_outliers_removed[['Distance ']].boxplot()
plt.show()

# %%
df_outliers_removed['engine_power'].median()
# Out:
# np.float64(91.0)

# %%
df_outliers_removed['engine_power'].fillna(df_outliers_removed['engine_power'].median(),inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_30616\3399911393.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_outliers_removed['engine_power'].fillna(df_outliers_removed['engine_power'].median(),inplace=True)

# %%
q1=df_outliers_removed['engine_power'].quantile(0.25)
q1
# Out:
# np.float64(74.0)

# %%
q3=df_outliers_removed['engine_power'].quantile(0.75)
q3
# Out:
# np.float64(112.0)

# %%
iqr=q3-q1
iqr
# Out:
# np.float64(38.0)

# %%
LL=q1-(1.5*iqr)
LL
# Out:
# np.float64(17.0)

# %%
UL=q3+(1.5*iqr)
UL
# Out:
# np.float64(169.0)

# %%
df_outliers_removed['engine_power']=df_outliers_removed['engine_power'][(df_outliers_removed['engine_power']>LL)& (df_outliers_removed['engine_power']<UL)]

# %%
df_outliers_removed[['engine_power']].boxplot()
plt.show()

# %%
df_outliers_removed.dropna(subset='engine_displacement',inplace=True)

# %%
df_outliers_removed.isnull().sum()
# Out:
# Id                         0
# Maker                      0
# model                      0
# Location                   0
# Distance                   0
# Owner Type                 0
# manufacture_year        1288
# Age of car              1288
# engine_displacement        0
# engine_power             719
# Vroom Audit Rating         0
# transmission               0
# door_count             47864
# seat_count              5327
# fuel_type                  0
# Price                    725
# Distance                  98
# dtype: int64

# %%
df_outliers_removed.drop(columns="door_count",inplace=True)

# %%
df_outliers_removed.dropna(subset="seat_count",inplace=True)

# %%
df_outliers_removed.dropna(subset="Price",inplace=True)

# %%
df_outliers_removed.dropna(subset="engine_power",inplace=True)

# %%
df_outliers_removed.dropna(subset="manufacture_year",inplace=True)

# %%
df_outliers_removed.dropna(subset="Age of car",inplace=True)

# %%
df_outliers_removed.isnull().sum()
# Out:
# Id                      0
# Maker                   0
# model                   0
# Location                0
# Distance                0
# Owner Type              0
# manufacture_year        0
# Age of car              0
# engine_displacement     0
# engine_power            0
# Vroom Audit Rating      0
# transmission            0
# seat_count              0
# fuel_type               0
# Price                   0
# Distance               84
# dtype: int64

# %%
df_outliers_removed.dropna(subset="Distance ",inplace=True)

# %%
df_outliers_removed.dtypes
# Out:
# Id                       int64
# Maker                    int64
# model                    int64
# Location                 int64
# Distance               float64
# Owner Type               int64
# manufacture_year       float64
# Age of car             float64
# engine_displacement    float64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission             int64
# seat_count             float64
# fuel_type                int64
# Price                  float64
# Distance               float64
# dtype: object

# %%
df_outliers_removed['Distance ']=le.fit_transform(df_outliers_removed['Distance '])

# %%
df_outliers_removed['Price']=le.fit_transform(df_outliers_removed['Price'])

# %%
df_outliers_removed["seat_count"]=le.fit_transform(df_outliers_removed["seat_count"])

# %%
df_outliers_removed["engine_power"]=le.fit_transform(df_outliers_removed["engine_power"])

# %%
df_outliers_removed["engine_displacement"]=le.fit_transform(df_outliers_removed["engine_displacement"])

# %%
df_outliers_removed["manufacture_year"]=le.fit_transform(df_outliers_removed["manufacture_year"])

# %%
df_outliers_removed["Age of car"]=le.fit_transform(df_outliers_removed["Age of car"])

# %%
df_outliers_removed.dtypes
# Out:
# Id                       int64
# Maker                    int64
# model                    int64
# Location                 int64
# Distance                 int64
# Owner Type               int64
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power             int64
# Vroom Audit Rating       int64
# transmission             int64
# seat_count               int64
# fuel_type                int64
# Price                    int64
# Distance               float64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
df_outliers_removed.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'Vroom Audit Rating', 'transmission', 'seat_count', 'fuel_type',
#        'Price', 'Distance'],
#       dtype='object')

# %%
X_train=df_outliers_removed[['Maker','model','Location','Distance ','Owner Type','manufacture_year','Age of car','engine_displacement','engine_power','transmission', 'fuel_type']]
y_train=df_outliers_removed[['Price']]

# %%
X_train
# Out:
#        Maker  model  Location  Distance   Owner Type  manufacture_year  \
# 2          1     18         5       5158           3                14
# 3          5      6         9       4999           3                11
# 5          6      8         2       1322           0                15
# 6          6     16         3      13219           1                 9
# 7          2      9         2       4152           2                10
# ...      ...    ...       ...        ...         ...               ...
# 53508      6      8         2      14851           1                 7
# 53509      7     21         2          0           3                15
# 53510      6      8         4       3736           1                14
# 53511      6      8         1      14352           1                 9
# 53512      1     18        10       3250           3                15
#
#        Age of car  engine_displacement  engine_power  transmission  fuel_type
# ...

# %%
y_train
# Out:
#        Price
# 2      14836
# 3       6466
# 5      11164
# 6       6054
# 7       1289
# ...      ...
# 53508   1386
# 53509   3870
# 53510   9753
# 53511   2466
# 53512  13604
#
# [40571 rows x 1 columns]

# %%
standardize=pd.DataFrame(ss.fit_transform(X_train),columns=X_train.columns)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train,y_train)
# Out:
# 0.8435941217172321

# %%
model.coef_
# Out:
# array([[-3.86974259e+02,  5.33966932e+01,  1.70764042e-01,
#         -3.09119755e-01,  7.39946199e+00,  1.79090943e+02,
#         -1.79090943e+02,  4.23626369e+00,  6.41219931e+01,
#         -1.03675758e+03, -1.14535432e+03]])

# %%
model.intercept_
# Out:
# array([6429.59266681])

# %%
y_predicted=pd.DataFrame(model.predict(X_train))
y_predicted
# Out:
#                   0
# 0      12166.470222
# 1       8444.708635
# 2      10315.187289
# 3       6857.707497
# 4       3606.638219
# ...             ...
# 40566   3034.929533
# 40567   5856.442141
# 40568   7018.936333
# 40569   2123.822360
# 40570  13115.306422
#
# [40571 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(y_train,y_predicted)

# %%
mse
# Out:
# np.float64(2907759.0142776533)

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_train,y_predicted)

# %%
mae
# Out:
# np.float64(1344.0772759210524)

# %%
df1=pd.read_csv("Test_Data_set.csv")

# %%
df1
# Out:
#          Id    Maker    model    Location  Distance       Owner Type  \
# 0     11001    skoda  octavia      Mumbai   150000.0           First
# 1     11002    skoda    rapid  Coimbatore    29376.0           Third
# 2     11003    skoda  octavia  Coimbatore    30563.0          Second
# 3     11004     audi       q3       Delhi     8650.0  Fourth & Above
# 4     11005     audi       tt     Chennai     6400.0           Third
# ...     ...      ...      ...         ...        ...             ...
# 5610  16611    skoda  octavia      Mumbai   149976.0           First
# 5611  16612    skoda   superb   Ahmedabad   332000.0           First
# 5612  16613    skoda  octavia   Bangalore   230800.0          Second
# 5613  16614   nissan  qashqai      Jaipur    63480.0           Third
# 5614  16615  hyundai      i30      Jaipur    75000.0          Second
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# ...

# %%
df1.shape
# Out:
# (5615, 16)

# %%
df1.isnull().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance                128
# Owner Type                0
# manufacture_year          0
# Age of car                0
# engine_displacement       0
# engine_power            168
# body_type              5193
# Vroom Audit Rating        0
# transmission              0
# door_count              806
# seat_count              891
# fuel_type                 0
# dtype: int64

# %%
df1.drop(columns="body_type",inplace=True)

# %%
df1.dropna(subset="Distance ",inplace=True)

# %%
df1.dropna(subset="engine_power",inplace=True)

# %%
df1["door_count"].fillna(df1["door_count"].mean(),inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_30616\1810236124.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["door_count"].fillna(df1["door_count"].mean(),inplace=True)

# %%
df1["seat_count"].fillna(df1["seat_count"].mean(),inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_30616\474947015.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["seat_count"].fillna(df1["seat_count"].mean(),inplace=True)

# %%
df1.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# dtype: int64

# %%
pd.get_dummies(data=df1,columns=['model'],prefix='model')
# Out:
#          Id    Maker    Location  Distance       Owner Type  manufacture_year  \
# 0     11001    skoda      Mumbai   150000.0           First              2007
# 1     11002    skoda  Coimbatore    29376.0           Third              2014
# 2     11003    skoda  Coimbatore    30563.0          Second              2014
# 3     11004     audi       Delhi     8650.0  Fourth & Above              2015
# 4     11005     audi     Chennai     6400.0           Third              2015
# ...     ...      ...         ...        ...             ...               ...
# 5610  16611    skoda      Mumbai   149976.0           First              2011
# 5611  16612    skoda   Ahmedabad   332000.0           First              2005
# 5612  16613    skoda   Bangalore   230800.0          Second              2005
# 5613  16614   nissan      Jaipur    63480.0           Third              2011
# 5614  16615  hyundai      Jaipur    75000.0          Second              2011
#
# ...

# %%
df1.replace({'True':1,'False':0})
# Out:
#          Id    Maker    model    Location  Distance       Owner Type  \
# 0     11001    skoda  octavia      Mumbai   150000.0           First
# 1     11002    skoda    rapid  Coimbatore    29376.0           Third
# 2     11003    skoda  octavia  Coimbatore    30563.0          Second
# 3     11004     audi       q3       Delhi     8650.0  Fourth & Above
# 4     11005     audi       tt     Chennai     6400.0           Third
# ...     ...      ...      ...         ...        ...             ...
# 5610  16611    skoda  octavia      Mumbai   149976.0           First
# 5611  16612    skoda   superb   Ahmedabad   332000.0           First
# 5612  16613    skoda  octavia   Bangalore   230800.0          Second
# 5613  16614   nissan  qashqai      Jaipur    63480.0           Third
# 5614  16615  hyundai      i30      Jaipur    75000.0          Second
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# ...

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.dtypes
# Out:
# Id                       int64
# Maker                   object
# model                   object
# Location                object
# Distance               float64
# Owner Type              object
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission            object
# door_count             float64
# seat_count             float64
# fuel_type               object
# dtype: object

# %%
df1.select_dtypes(include=object)
# Out:
#         Maker    model    Location      Owner Type transmission fuel_type
# 0       skoda  octavia      Mumbai           First          man    petrol
# 1       skoda    rapid  Coimbatore           Third          man    diesel
# 2       skoda  octavia  Coimbatore          Second          man    diesel
# 3        audi       q3       Delhi  Fourth & Above         auto    diesel
# 4        audi       tt     Chennai           Third         auto    petrol
# ...       ...      ...         ...             ...          ...       ...
# 5610    skoda  octavia      Mumbai           First          man    diesel
# 5611    skoda   superb   Ahmedabad           First          man    diesel
# 5612    skoda  octavia   Bangalore          Second          man    diesel
# 5613   nissan  qashqai      Jaipur           Third          man    petrol
# 5614  hyundai      i30      Jaipur          Second          man    petrol
#
# [5348 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df1["Maker"]=le.fit_transform(df1["Maker"])

# %%
df1["model"]=le.fit_transform(df1["model"])

# %%
df1["Location"]=le.fit_transform(df1["Location"])

# %%
df1["Owner Type"]=le.fit_transform(df1["Owner Type"])

# %%
df1["transmission"]=le.fit_transform(df1["transmission"])

# %%
df1["fuel_type"]=le.fit_transform(df1["fuel_type"])

# %%
df1
# Out:
#          Id  Maker  model  Location  Distance   Owner Type  manufacture_year  \
# 0     11001      6      8         9   150000.0           0              2007
# 1     11002      6     14         3    29376.0           3              2014
# 2     11003      6      8         3    30563.0           2              2014
# 3     11004      0     10         4     8650.0           1              2015
# 4     11005      0     17         2     6400.0           3              2015
# ...     ...    ...    ...       ...        ...         ...               ...
# 5610  16611      6      8         9   149976.0           0              2011
# 5611  16612      6     16         0   332000.0           0              2005
# 5612  16613      6      8         1   230800.0           2              2005
# 5613  16614      5     13         6    63480.0           3              2011
# 5614  16615      3      5         6    75000.0           2              2011
#
# ...

# %%
df1.dtypes
# Out:
# Id                       int64
# Maker                    int64
# model                    int64
# Location                 int64
# Distance               float64
# Owner Type               int64
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission             int64
# door_count             float64
# seat_count             float64
# fuel_type                int64
# dtype: object

# %%
df1.boxplot()
plt.show()

# %%
q1=df1.quantile(0.25)

# %%
q3=df1.quantile(0.75)

# %%
iqr=q3-q1

# %%
l1=q1-(1.5*iqr)

# %%
u1=q3+(1.5*iqr)

# %%
df1_outliers_removed=df1[(df1>l1)&(df1<u1)]

# %%
df1_outliers_removed.boxplot()
plt.show()

# %%
df1_outliers_removed
# Out:
#          Id  Maker  model  Location  Distance   Owner Type  manufacture_year  \
# 0     11001      6      8         9   150000.0           0            2007.0
# 1     11002      6     14         3    29376.0           3            2014.0
# 2     11003      6      8         3    30563.0           2            2014.0
# 3     11004      0     10         4     8650.0           1            2015.0
# 4     11005      0     17         2     6400.0           3            2015.0
# ...     ...    ...    ...       ...        ...         ...               ...
# 5610  16611      6      8         9   149976.0           0            2011.0
# 5611  16612      6     16         0        NaN           0            2005.0
# 5612  16613      6      8         1   230800.0           2            2005.0
# 5613  16614      5     13         6    63480.0           3            2011.0
# 5614  16615      3      5         6    75000.0           2            2011.0
#
# ...

# %%
df1_outliers_removed.isnull().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance                 54
# Owner Type                0
# manufacture_year        130
# Age of car              130
# engine_displacement     511
# engine_power            130
# Vroom Audit Rating        0
# transmission              0
# door_count             5348
# seat_count             5348
# fuel_type                 0
# dtype: int64

# %%
df1_outliers_removed.drop(columns="door_count",inplace=True)

# %%
df1_outliers_removed.drop(columns="seat_count",inplace=True)

# %%
df1_outliers_removed.dropna(subset="Distance ",inplace=True)

# %%
df1_outliers_removed.dropna(subset="manufacture_year",inplace=True)

# %%
df1_outliers_removed.dropna(subset="Age of car",inplace=True)

# %%
df1_outliers_removed.dropna(subset="engine_displacement",inplace=True)

# %%
df1_outliers_removed.dropna(subset="engine_power",inplace=True)

# %%
df1_outliers_removed.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# fuel_type              0
# dtype: int64

# %%
df1_outliers_removed.dtypes
# Out:
# Id                       int64
# Maker                    int64
# model                    int64
# Location                 int64
# Distance               float64
# Owner Type               int64
# manufacture_year       float64
# Age of car             float64
# engine_displacement    float64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission             int64
# fuel_type                int64
# dtype: object

# %%
df1_outliers_removed["Distance "]=le.fit_transform(df1_outliers_removed["Distance "])

# %%
df1_outliers_removed["manufacture_year"]=le.fit_transform(df1_outliers_removed["manufacture_year"])

# %%
df1_outliers_removed["Age of car"]=le.fit_transform(df1_outliers_removed["Age of car"])

# %%
df1_outliers_removed["engine_displacement"]=le.fit_transform(df1_outliers_removed["engine_displacement"])

# %%
df1_outliers_removed["engine_power"]=le.fit_transform(df1_outliers_removed["engine_power"])

# %%
df1_outliers_removed.dtypes
# Out:
# Id                     int64
# Maker                  int64
# model                  int64
# Location               int64
# Distance               int64
# Owner Type             int64
# manufacture_year       int64
# Age of car             int64
# engine_displacement    int64
# engine_power           int64
# Vroom Audit Rating     int64
# transmission           int64
# fuel_type              int64
# dtype: object

# %%
X_test=df1_outliers_removed[['Maker','model','Location','Owner Type','transmission','fuel_type','Distance ','engine_power','manufacture_year','Age of car','engine_displacement']]

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
standardize1=pd.DataFrame(ss.fit_transform(X_test),columns=X_test.columns)
standardize1
# Out:
#          Maker     model  Location  Owner Type  transmission  fuel_type  \
# 0     0.557314 -0.447921  1.270500   -1.291786      0.557678   0.993154
# 1     0.557314  0.527952 -0.625684    1.350787      0.557678  -1.006894
# 2     0.557314 -0.447921 -0.625684    0.469929      0.557678  -1.006894
# 3    -1.966720 -0.122630 -0.309653   -0.410928     -1.793149  -1.006894
# 4    -1.966720  1.015889 -0.941715    1.350787     -1.793149   0.993154
# ...        ...       ...       ...         ...           ...        ...
# 4653 -1.966720 -1.098503  0.322408    0.469929      0.557678  -1.006894
# 4654  0.557314 -0.447921  1.270500   -1.291786      0.557678  -1.006894
# 4655  0.557314 -0.447921 -1.257745    0.469929      0.557678  -1.006894
# 4656  0.136642  0.365307  0.322408    1.350787      0.557678   0.993154
# 4657 -0.704703 -0.935858  0.322408    0.469929      0.557678   0.993154
#
#       Distance   engine_power  manufacture_year  Age of car  \
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
y_predicted=pd.DataFrame(model.predict(X_test))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 y_predicted=pd.DataFrame(model.predict(X_test))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:283, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
# --> 283     check_is_fitted(self)
#     285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#
# ...

# %%
y_predicted=model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 y_predicted=model.predict(X_test)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:283, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
# --> 283     check_is_fitted(self)
#     285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#
# ...

# %%
y_predicted
# Out:
#                   0
# 0      12166.470222
# 1       8444.708635
# 2      10315.187289
# 3       6857.707497
# 4       3606.638219
# ...             ...
# 40566   3034.929533
# 40567   5856.442141
# 40568   7018.936333
# 40569   2123.822360
# 40570  13115.306422
#
# [40571 rows x 1 columns]

# %%
final=pd.concat((df1["Id"],y_predicted),axis=1)

# %%
final
# Out:
#             Id             0
# 0      11001.0  12166.470222
# 1      11002.0   8444.708635
# 2      11003.0  10315.187289
# 3      11004.0   6857.707497
# 4      11005.0   3606.638219
# ...        ...           ...
# 40566      NaN   3034.929533
# 40567      NaN   5856.442141
# 40568      NaN   7018.936333
# 40569      NaN   2123.822360
# 40570      NaN  13115.306422
#
# [40571 rows x 2 columns]

# %%
df1.to_csv("final.csv")
